# %% [markdown]
# #trabajo de compresión

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import files

# %% [markdown]
# ##vacas sanas

# %%
archivoVaca = files.upload()
# Out:
#      <input type="file" id="files-4cd44e8c-aae5-402d-b369-537f295ae531" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4cd44e8c-aae5-402d-b369-537f295ae531">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving san1.csv to san1 (2).csv

# %%
dfSana1 = pd.read_csv("san1.csv", sep=',',header=None)
mSana1 = np.matrix(dfSana1)

plt.gray()
plt.imshow(mSana1)

# %%
mSana11 = mSana1.compress([False,True,True],axis=0)

plt.imshow(mSana11)

# %%
archivoVaca = files.upload()
# Out:
#      <input type="file" id="files-483ee567-afd0-4d2c-8bca-57ec0b5c6eff" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-483ee567-afd0-4d2c-8bca-57ec0b5c6eff">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving san2.csv to san2 (2).csv

# %%
dfSana2 = pd.read_csv("san2.csv", sep=',',header=None)
mSana2 = np.matrix(dfSana2)

plt.gray()
plt.imshow(mSana2)

# %%
mSana22 = mSana2.compress([False,True,True],axis=0)

plt.imshow(mSana22)

# %%
archivoVaca = files.upload()
# Out:
#      <input type="file" id="files-e8c33e9e-751e-495a-8304-3a868ea12c76" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e8c33e9e-751e-495a-8304-3a868ea12c76">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving san3.csv to san3 (3).csv

# %%
dfSana3 = pd.read_csv("san3.csv", sep=',',header=None)
mSana3 = np.matrix(dfSana3)

plt.gray()
plt.imshow(mSana3)

# %%
mSana33 = mSana3.compress([False,True,True],axis=0)

plt.imshow(mSana33)

# %%
archivoVaca = files.upload()
# Out:
#      <input type="file" id="files-05d533f5-af7f-4011-9312-6c046b14266b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-05d533f5-af7f-4011-9312-6c046b14266b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving san4.csv to san4 (1).csv

# %%
dfSana4 = pd.read_csv("san4.csv", sep=',',header=None)
mSana4 = np.matrix(dfSana4)

plt.gray()
plt.imshow(mSana4)

# %%
mSana44 = mSana4.compress([False,True,True],axis=0)

plt.imshow(mSana44)

# %%
archivoVaca = files.upload()
# Out:
#      <input type="file" id="files-cce63ae5-82e5-47a7-aa34-76720309d46b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cce63ae5-82e5-47a7-aa34-76720309d46b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving san5.csv to san5 (1).csv

# %%
dfSana5 = pd.read_csv("san5.csv", sep=',',header=None)
mSana5 = np.matrix(dfSana5)

plt.gray()
plt.imshow(mSana5)

# %%
mSana55 = mSana5.compress([False,True,True],axis=0)

plt.imshow(mSana55)

# %% [markdown]
# ##vacas enfermas

# %%
archivoVaca = files.upload()
# Out:
#      <input type="file" id="files-5e8c057c-fe93-45c2-b543-8434aa17c329" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5e8c057c-fe93-45c2-b543-8434aa17c329">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving enf1.csv to enf1 (1).csv

# %%
dfEnferma1 = pd.read_csv("enf1.csv", sep=',',header=None)
mEnferma1 = np.matrix(dfEnferma1)

plt.gray()
plt.imshow(mEnferma1)

# %%
mEnferma11 = mEnferma1.compress([False,True,True],axis=0)

plt.imshow(mEnferma11)

# %%
archivoVaca = files.upload()
# Out:
#      <input type="file" id="files-84bdcb79-3ee8-4234-84ff-4cfb0ca2f788" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-84bdcb79-3ee8-4234-84ff-4cfb0ca2f788">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving enf2.csv to enf2 (1).csv

# %%
dfEnferma2 = pd.read_csv("enf2.csv", sep=',',header=None)
mEnferma2 = np.matrix(dfEnferma2)

plt.gray()
plt.imshow(mEnferma2)

# %%
mEnferma22 = mEnferma2.compress([False,True,True],axis=0)

plt.imshow(mEnferma22)

# %%
archivoVaca = files.upload()
# Out:
#      <input type="file" id="files-a1f4985f-aef5-4b1b-9458-3ef2eae19b7c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a1f4985f-aef5-4b1b-9458-3ef2eae19b7c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving enf3.csv to enf3 (1).csv

# %%
dfEnferma3 = pd.read_csv("enf3.csv", sep=',',header=None)
mEnferma3 = np.matrix(dfEnferma3)

plt.gray()
plt.imshow(mEnferma3)

# %%
mEnferma33 = mEnferma3.compress([False,True,True],axis=0)

plt.imshow(mEnferma33)

# %%
archivoVaca = files.upload()
# Out:
#      <input type="file" id="files-d0ca1cc5-ba26-4db1-a94b-2ab095d31e62" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d0ca1cc5-ba26-4db1-a94b-2ab095d31e62">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving enf4.csv to enf4 (1).csv

# %%
dfEnferma4 = pd.read_csv("enf4.csv", sep=',',header=None)
mEnferma4 = np.matrix(dfEnferma4)

plt.gray()
plt.imshow(mEnferma4)

# %%
mEnferma44 = mEnferma4.compress([False,True,True],axis=0)

plt.imshow(mEnferma44)

# %%
archivoVaca = files.upload()
# Out:
#      <input type="file" id="files-9e4190be-a815-4c2e-b852-b8a257cde3d6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9e4190be-a815-4c2e-b852-b8a257cde3d6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving enf5.csv to enf5 (1).csv

# %%
dfEnferma5 = pd.read_csv("enf5.csv", sep=',',header=None)
mEnferma5 = np.matrix(dfEnferma5)

plt.gray()
plt.imshow(mEnferma5)

# %%
mEnferma55 = mEnferma5.compress([False,True,True],axis=0)

plt.imshow(mEnferma55)
